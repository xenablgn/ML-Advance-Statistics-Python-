# %% [markdown]
# ![New York City schoolbus](schoolbus.jpg)
#
# Photo by [Jannis Lucas](https://unsplash.com/@jannis_lucas) on [Unsplash](https://unsplash.com).
# <br>
#
# Every year, American high school students take SATs, which are standardized tests intended to measure literacy, numeracy, and writing skills. There are three sections - reading, math, and writing, each with a maximum score of 800 points. These tests are extremely important for students and colleges, as they play a pivotal role in the admissions process.
#
# Analyzing the performance of schools is important for a variety of stakeholders, including policy and education professionals, researchers, government, and even parents considering which school their children should attend.
#
# You have been provided with a dataset called `schools.csv`, which is previewed below.
#
# You have been tasked with answering three key questions about New York City (NYC) public school SAT performance.

# %%
# Re-run this cell 
import pandas as pd

# Read in the data
schools = pd.read_csv("schools.csv")

# Preview the data
schools.head()

# Start coding here...

# Which schools are best for math?
best_math_schools = schools[schools["average_math"] >= 640][["school_name", "average_math"]].sort_values("average_math", ascending=False)

# Calculate total_SAT per school
schools["total_SAT"] = schools["average_math"] + schools["average_reading"] + schools["average_writing"]

# Who are the top 10 performing schools?
top_10_schools = schools.groupby("school_name")["total_SAT"].mean().reset_index().sort_values("total_SAT", ascending=False).head(10)

# Which NYC borough has the highest standard deviation for total_SAT?
boroughs = schools.groupby("borough")["total_SAT"].agg(["count", "mean", "std"]).round(2)

# Filter for max std and reset index so borough is a column
largest_std_dev = boroughs[boroughs["std"] == boroughs["std"].max()]

# Rename the columns for clarity
largest_std_dev = largest_std_dev.rename(columns={"count": "num_schools", "mean": "average_SAT", "std": "std_SAT"})

print(best_math_schools)
print(top_10_schools)
print(largest_std_dev)
# Out:
#                                            school_name  average_math
# 88                              Stuyvesant High School           754
# 170                       Bronx High School of Science           714
# 93                 Staten Island Technical High School           711
# 365  Queens High School for the Sciences at York Co...           701
# 68   High School for Mathematics, Science, and Engi...           683
# 280                     Brooklyn Technical High School           682
# 333                        Townsend Harris High School           680
# 174  High School of American Studies at Lehman College           669
# 0    New Explorations into Science, Technology and ...           657
# 45                       Eleanor Roosevelt High School           641
#                                            school_name  total_SAT
# 325                             Stuyvesant High School     2144.0
# 324                Staten Island Technical High School     2041.0
# ...

# %%
#################################### SECOND SOLUTION ####################################



#### 1):

# Re-run this cell 
import pandas as pd
# Read in the data
schools = pd.read_csv("schools.csv")
# Preview the data
schools.head()
threshold = schools["average_math"].max() * 0.8
print(threshold)
best_math_schools = schools.loc[schools["average_math"] >= 640, ["average_math", "school_name"]].sort_values(by="average_math", ascending=False)
print(best_math_schools)

#### 2):
scores=["average_math", "average_reading", "average_writing"]
cumulative_sum_schools = schools.set_index("school_name").groupby("school_name")[scores].cumsum(axis=0).sum(axis=1).reset_index(name="total_SAT").sort_values("total_SAT", ascending=False)
# Select top 10 schools and reset index
top_10_schools = cumulative_sum_schools.iloc[0:10,:].reset_index(drop=True)
# Print the top 10 schools
print(top_10_schools)


### 3):

# cumulative sum, name the column
cumulative_sum_schools = schools.set_index("borough").groupby("borough")[scores].cumsum(axis=0).sum(axis=1).reset_index(name="total_SAT")
# Get the counts of each "borough"
borough_counts = schools["borough"].value_counts().reset_index()
borough_counts.columns = ["borough", "num_schools"]
# Merge counts back into the DataFrame
cumulative_sum_schools = pd.merge(cumulative_sum_schools, borough_counts, on="borough")
# Group by "borough" and calculate mean, standard deviation, and number of schools
# 'first' is used to indicate that for the 'num_schools' column, the first value encountered within each group (borough) should be used.
largest_std_dev = cumulative_sum_schools.groupby("borough").agg({'total_SAT': [np.mean, np.std], 'num_schools': 'first'}).round(2)
largest_std_dev.columns = ['average_SAT', 'std_SAT', "num_schools"]
print(largest_std_dev)
largest_std_dev = boroughs[boroughs["std"] == boroughs["std"].max()]

# Print the result
print(largest_std_dev)
